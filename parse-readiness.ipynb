# %%
import pandas as pd
df = pd.read_csv("mockdata.csv", low_memory=False)
unique_uics = df.UIC.unique() 
print("Total rows: {0}  Total columns: {1}  Total UICs: {2}".format(df.shape[0], df.shape[1], unique_uics.size))
print(list(df))
# Out:
# Total rows: 110  Total columns: 21  Total UICs: 12
# ['RICDA', 'UIC', 'LNAME', 'ParentUIC', 'Parent level to child', 'Parent Lname', 'UTC', 'MJCOM_NAME', 'SVC', 'COMPOCD', 'TREAD', 'READY', 'REASN', 'PRRAT', 'PRRES', 'ESRAT', 'ESRES', 'ERRAT', 'ERRES', 'TRRAT', 'TRRES']

# %%
df.head()
# Out:
#         RICDA UIC LNAME ParentUIC  Parent level to child Parent Lname  UTC  \
# 0  2015-10-19  A1  Aone        A1                      0         Aone  XYZ
# 1  2015-10-19  A1  Aone        B1                      1         Bone  XYZ
# 2  2015-10-19  A1  Aone        C1                      2         Cone  XYZ
# 3  2015-10-19  A1  Aone        D1                      3         Done  XYZ
# 4  2015-10-19  A1  Aone        D2                      3         Dtwo  XYZ
#
#   MJCOM_NAME SVC COMPOCD  ...   READY  REASN PRRAT  PRRES ESRAT  ESRES ERRAT  \
# 0        ANG   F       G  ...       3      S     1    NaN     3    S84     1
# 1        ANG   F       G  ...       3      S     1    NaN     3    S84     1
# 2        ANG   F       G  ...       3      S     1    NaN     3    S84     1
# 3        ANG   F       G  ...       3      S     1    NaN     3    S84     1
# 4        ANG   F       G  ...       3      S     1    NaN     3    S84     1
#
#    ERRES TRRAT  TRRES
# 0    NaN     1    NaN
# 1    NaN     1    NaN
# 2    NaN     1    NaN
# 3    NaN     1    NaN
# 4    NaN     1    NaN
#
# [5 rows x 21 columns]

# %%
df[df['UIC'] == 'E1']['Parent level to child'].isin([1]).any()
# Out:
# False

# %%
#find root UICs
def get_root_nodes():
    root_nodes = []
    for uic in unique_uics:
        #print(uic)
        if not (df[df['UIC'] == uic]['Parent level to child'].isin([1]).any()):
            root_nodes.append(uic)
    return(root_nodes)
        
    #if 1 in (df['Parent level to child'] == uic):
    
print(get_root_nodes())
# Out:
# ['E1']

# %%
df = df.loc[(df['Parent level to child'] == 1) | (df['UIC'].isin(get_root_nodes()))]

# %%
df
# Out:
#           RICDA UIC   LNAME ParentUIC  Parent level to child Parent Lname  \
# 1    2015-10-19  A1    Aone        B1                      1         Bone
# 7    2015-10-22  B1    Bone        C1                      1         Cone
# 12   2015-10-23  C1    Cone        D1                      1         Done
# 13   2015-10-23  C1    Cone        D2                      1         Dtwo
# 16   2015-10-24  D1    Eone        E1                      1         Eone
# 18   2015-10-25  D2    Dtwo        E1                      1         Eone
# 19   2015-10-30  E1    Eone        E1                      0         Eone
# 21   2015-10-19  A2    Atwo        B1                      1         Bone
# 27   2015-10-19  A3  Athree        B1                      1         Bone
# 33   2015-10-21  B2    Btwo        C1                      1         Cone
# 38   2015-10-19  A4   Afour        B1                      1         Bone
# 44   2015-10-20  A5   Afive        B1                      1         Bone
# 50   2015-10-19  A6    Asix        B1                      1         Bone
# 56   2015-11-20  A1    Aone        B1                      1         Bone
# 62   2015-11-23  B1    Bone        C1                      1         Cone
# 67   2015-11-24  C1    Cone        D1                      1         Done
# 68   2015-11-24  C1    Cone        D2                      1         Dtwo
# 71   2015-11-25  D1    Eone        E1                      1         Eone
# 73   2015-11-26  D2    Dtwo        E1                      1         Eone
# 74   2015-12-01  E1    Eone        E1                      0         Eone
# 76   2015-11-20  A2    Atwo        B1                      1         Bone
# 82   2015-11-20  A3  Athree        B1                      1         Bone
# 88   2015-11-22  B2    Btwo        C1                      1         Cone
# 93   2015-11-20  A4   Afour        B1                      1         Bone
# 99   2015-11-21  A5   Afive        B1                      1         Bone
# 105  2015-11-20  A6    Asix        B1                      1         Bone
#
#      UTC MJCOM_NAME SVC COMPOCD  ...   READY  REASN PRRAT  PRRES ESRAT  ESRES  \
# 1    XYZ        ANG   F       G  ...       3      S     1    NaN     3    S84
# 7    XYZ        ANG   F       G  ...       2      X     1    NaN     2    S86
# 12   XYZ        ANG   F       G  ...       2      X     2    P30     2    S67
# 13   XYZ        ANG   F       G  ...       2      X     2    P30     2    S67
# 16   XYZ        ANG   F       G  ...       2      X     2    P50     2    S68
# 18   XYZ        ANG   F       G  ...       3      P     3    P80     2    S57
# 19   XYZ        ANG   F       G  ...       3      P     3    P70     2    S61
# 21   XYZ        ANG   F       G  ...       4      R     1    NaN     1    NaN
# 27   XYZ        ANG   F       G  ...       3      T     1    NaN     1    NaN
# 33   XYZ        ANG   F       G  ...       3      P     3    P54     2    S97
# 38   XYZ        ANG   F       G  ...       3      X     3    P95     3    S39
# 44   XYZ        ANG   F       G  ...       2      T     1    NaN     1    NaN
# 50   XYZ        ANG   F       G  ...       4      P     4    P45     2    S21
# 56   XYZ        ANG   F       G  ...       3      S     1    NaN     3    S85
# 62   XYZ        ANG   F       G  ...       3      T     1    NaN     1    NaN
# 67   XYZ        ANG   F       G  ...       2      X     2    P89     1    NaN
# 68   XYZ        ANG   F       G  ...       2      X     2    P89     1    NaN
# 71   XYZ        ANG   F       G  ...       3      S     2    P21     3    S40
# 73   XYZ        ANG   F       G  ...       3      S     2    P81     3    S99
# 74   XYZ        ANG   F       G  ...       3      P     3    P49     1    NaN
# 76   XYZ        ANG   F       G  ...       4      R     1    NaN     1    NaN
# 82   XYZ        ANG   F       G  ...       3      T     1    NaN     1    NaN
# 88   XYZ        ANG   F       G  ...       4      P     4    P19     2    S50
# 93   XYZ        ANG   F       G  ...       4      S     3    P43     4    S65
# 99   XYZ        ANG   F       G  ...       2      T     1    NaN     1    NaN
# 105  XYZ        ANG   F       G  ...       4      X     4    P18     3    S98
#
#     ERRAT  ERRES TRRAT  TRRES
# 1       1    NaN     1    NaN
# 7       2    R22     2    T34
# 12      2    R25     2    T13
# 13      2    R25     2    T13
# 16      2    R73     2    T13
# 18      2    R39     2    T14
# 19      2    R31     2    T52
# 21      4    R65     1    NaN
# 27      2    R19     3    T29
# 33      2    R88     1    NaN
# 38      1    NaN     1    NaN
# 44      1    NaN     2    T49
# 50      4    R16     1    NaN
# 56      1    NaN     1    NaN
# 62      2    R53     3    T13
# 67      2    R64     2    T12
# 68      2    R64     2    T12
# 71      2    R54     2    T29
# 73      2    R54     2    T29
# 74      1    NaN     2    T34
# 76      4    R80     1    NaN
# 82      2    R44     3    T67
# 88      1    NaN     1    NaN
# 93      1    NaN     1    NaN
# 99      1    NaN     2    T78
# 105     4    R69     1    NaN
#
# [26 rows x 21 columns]

# %%
type(df['RICDA'].iloc[0])
# Out:
# str

# %%
df['RICDA'] = pd.to_datetime(df['RICDA'])
# Out:
# /Users/bcbarsness/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df
# Out:
#          RICDA UIC   LNAME ParentUIC  Parent level to child Parent Lname  UTC  \
# 1   2015-10-19  A1    Aone        B1                      1         Bone  XYZ
# 7   2015-10-22  B1    Bone        C1                      1         Cone  XYZ
# 12  2015-10-23  C1    Cone        D1                      1         Done  XYZ
# 13  2015-10-23  C1    Cone        D2                      1         Dtwo  XYZ
# 16  2015-10-24  D1    Eone        E1                      1         Eone  XYZ
# 18  2015-10-25  D2    Dtwo        E1                      1         Eone  XYZ
# 21  2015-10-19  A2    Atwo        B1                      1         Bone  XYZ
# 27  2015-10-19  A3  Athree        B1                      1         Bone  XYZ
# 33  2015-10-21  B2    Btwo        C1                      1         Cone  XYZ
# 38  2015-10-19  A4   Afour        B1                      1         Bone  XYZ
# 44  2015-10-20  A5   Afive        B1                      1         Bone  XYZ
# 50  2015-10-19  A6    Asix        B1                      1         Bone  XYZ
# 56  2015-11-20  A1    Aone        B1                      1         Bone  XYZ
# 62  2015-11-23  B1    Bone        C1                      1         Cone  XYZ
# 67  2015-11-24  C1    Cone        D1                      1         Done  XYZ
# 68  2015-11-24  C1    Cone        D2                      1         Dtwo  XYZ
# 71  2015-11-25  D1    Eone        E1                      1         Eone  XYZ
# 73  2015-11-26  D2    Dtwo        E1                      1         Eone  XYZ
# 76  2015-11-20  A2    Atwo        B1                      1         Bone  XYZ
# 82  2015-11-20  A3  Athree        B1                      1         Bone  XYZ
# 88  2015-11-22  B2    Btwo        C1                      1         Cone  XYZ
# 93  2015-11-20  A4   Afour        B1                      1         Bone  XYZ
# 99  2015-11-21  A5   Afive        B1                      1         Bone  XYZ
# 105 2015-11-20  A6    Asix        B1                      1         Bone  XYZ
#
#     MJCOM_NAME SVC COMPOCD  ...   READY  REASN PRRAT  PRRES ESRAT  ESRES  \
# 1          ANG   F       G  ...       3      S     1    NaN     3    S84
# 7          ANG   F       G  ...       2      X     1    NaN     2    S86
# 12         ANG   F       G  ...       2      X     2    P30     2    S67
# 13         ANG   F       G  ...       2      X     2    P30     2    S67
# 16         ANG   F       G  ...       2      X     2    P50     2    S68
# 18         ANG   F       G  ...       3      P     3    P80     2    S57
# 21         ANG   F       G  ...       4      R     1    NaN     1    NaN
# 27         ANG   F       G  ...       3      T     1    NaN     1    NaN
# 33         ANG   F       G  ...       3      P     3    P54     2    S97
# 38         ANG   F       G  ...       3      X     3    P95     3    S39
# 44         ANG   F       G  ...       2      T     1    NaN     1    NaN
# 50         ANG   F       G  ...       4      P     4    P45     2    S21
# 56         ANG   F       G  ...       3      S     1    NaN     3    S85
# 62         ANG   F       G  ...       3      T     1    NaN     1    NaN
# 67         ANG   F       G  ...       2      X     2    P89     1    NaN
# 68         ANG   F       G  ...       2      X     2    P89     1    NaN
# 71         ANG   F       G  ...       3      S     2    P21     3    S40
# 73         ANG   F       G  ...       3      S     2    P81     3    S99
# 76         ANG   F       G  ...       4      R     1    NaN     1    NaN
# 82         ANG   F       G  ...       3      T     1    NaN     1    NaN
# 88         ANG   F       G  ...       4      P     4    P19     2    S50
# 93         ANG   F       G  ...       4      S     3    P43     4    S65
# 99         ANG   F       G  ...       2      T     1    NaN     1    NaN
# 105        ANG   F       G  ...       4      X     4    P18     3    S98
#
#     ERRAT  ERRES TRRAT  TRRES
# 1       1    NaN     1    NaN
# 7       2    R22     2    T34
# 12      2    R25     2    T13
# 13      2    R25     2    T13
# 16      2    R73     2    T13
# 18      2    R39     2    T14
# 21      4    R65     1    NaN
# 27      2    R19     3    T29
# 33      2    R88     1    NaN
# 38      1    NaN     1    NaN
# 44      1    NaN     2    T49
# 50      4    R16     1    NaN
# 56      1    NaN     1    NaN
# 62      2    R53     3    T13
# 67      2    R64     2    T12
# 68      2    R64     2    T12
# 71      2    R54     2    T29
# 73      2    R54     2    T29
# 76      4    R80     1    NaN
# 82      2    R44     3    T67
# 88      1    NaN     1    NaN
# 93      1    NaN     1    NaN
# 99      1    NaN     2    T78
# 105     4    R69     1    NaN
#
# [24 rows x 21 columns]

# %%
df[df.groupby(['UIC'])['RICDA'].transform(max) == df['RICDA']]
# Out:
#           RICDA UIC   LNAME ParentUIC  Parent level to child Parent Lname  \
# 56   2015-11-20  A1    Aone        B1                      1         Bone
# 62   2015-11-23  B1    Bone        C1                      1         Cone
# 67   2015-11-24  C1    Cone        D1                      1         Done
# 68   2015-11-24  C1    Cone        D2                      1         Dtwo
# 71   2015-11-25  D1    Eone        E1                      1         Eone
# 73   2015-11-26  D2    Dtwo        E1                      1         Eone
# 74   2015-12-01  E1    Eone        E1                      0         Eone
# 76   2015-11-20  A2    Atwo        B1                      1         Bone
# 82   2015-11-20  A3  Athree        B1                      1         Bone
# 88   2015-11-22  B2    Btwo        C1                      1         Cone
# 93   2015-11-20  A4   Afour        B1                      1         Bone
# 99   2015-11-21  A5   Afive        B1                      1         Bone
# 105  2015-11-20  A6    Asix        B1                      1         Bone
#
#      UTC MJCOM_NAME SVC COMPOCD  ...   READY  REASN PRRAT  PRRES ESRAT  ESRES  \
# 56   XYZ        ANG   F       G  ...       3      S     1    NaN     3    S85
# 62   XYZ        ANG   F       G  ...       3      T     1    NaN     1    NaN
# 67   XYZ        ANG   F       G  ...       2      X     2    P89     1    NaN
# 68   XYZ        ANG   F       G  ...       2      X     2    P89     1    NaN
# 71   XYZ        ANG   F       G  ...       3      S     2    P21     3    S40
# 73   XYZ        ANG   F       G  ...       3      S     2    P81     3    S99
# 74   XYZ        ANG   F       G  ...       3      P     3    P49     1    NaN
# 76   XYZ        ANG   F       G  ...       4      R     1    NaN     1    NaN
# 82   XYZ        ANG   F       G  ...       3      T     1    NaN     1    NaN
# 88   XYZ        ANG   F       G  ...       4      P     4    P19     2    S50
# 93   XYZ        ANG   F       G  ...       4      S     3    P43     4    S65
# 99   XYZ        ANG   F       G  ...       2      T     1    NaN     1    NaN
# 105  XYZ        ANG   F       G  ...       4      X     4    P18     3    S98
#
#     ERRAT  ERRES TRRAT  TRRES
# 56      1    NaN     1    NaN
# 62      2    R53     3    T13
# 67      2    R64     2    T12
# 68      2    R64     2    T12
# 71      2    R54     2    T29
# 73      2    R54     2    T29
# 74      1    NaN     2    T34
# 76      4    R80     1    NaN
# 82      2    R44     3    T67
# 88      1    NaN     1    NaN
# 93      1    NaN     1    NaN
# 99      1    NaN     2    T78
# 105     4    R69     1    NaN
#
# [13 rows x 21 columns]

# %%
df = df[idx]
df
# Out:
#           RICDA UIC   LNAME ParentUIC  Parent level to child Parent Lname  \
# 56   2015-11-20  A1    Aone        B1                      1         Bone
# 62   2015-11-23  B1    Bone        C1                      1         Cone
# 67   2015-11-24  C1    Cone        D1                      1         Done
# 68   2015-11-24  C1    Cone        D2                      1         Dtwo
# 71   2015-11-25  D1    Eone        E1                      1         Eone
# 73   2015-11-26  D2    Dtwo        E1                      1         Eone
# 74   2015-12-01  E1    Eone        E1                      0         Eone
# 76   2015-11-20  A2    Atwo        B1                      1         Bone
# 82   2015-11-20  A3  Athree        B1                      1         Bone
# 88   2015-11-22  B2    Btwo        C1                      1         Cone
# 93   2015-11-20  A4   Afour        B1                      1         Bone
# 99   2015-11-21  A5   Afive        B1                      1         Bone
# 105  2015-11-20  A6    Asix        B1                      1         Bone
#
#      UTC MJCOM_NAME SVC COMPOCD  ...   READY  REASN PRRAT  PRRES ESRAT  ESRES  \
# 56   XYZ        ANG   F       G  ...       3      S     1    NaN     3    S85
# 62   XYZ        ANG   F       G  ...       3      T     1    NaN     1    NaN
# 67   XYZ        ANG   F       G  ...       2      X     2    P89     1    NaN
# 68   XYZ        ANG   F       G  ...       2      X     2    P89     1    NaN
# 71   XYZ        ANG   F       G  ...       3      S     2    P21     3    S40
# 73   XYZ        ANG   F       G  ...       3      S     2    P81     3    S99
# 74   XYZ        ANG   F       G  ...       3      P     3    P49     1    NaN
# 76   XYZ        ANG   F       G  ...       4      R     1    NaN     1    NaN
# 82   XYZ        ANG   F       G  ...       3      T     1    NaN     1    NaN
# 88   XYZ        ANG   F       G  ...       4      P     4    P19     2    S50
# 93   XYZ        ANG   F       G  ...       4      S     3    P43     4    S65
# 99   XYZ        ANG   F       G  ...       2      T     1    NaN     1    NaN
# 105  XYZ        ANG   F       G  ...       4      X     4    P18     3    S98
#
#     ERRAT  ERRES TRRAT  TRRES
# 56      1    NaN     1    NaN
# 62      2    R53     3    T13
# 67      2    R64     2    T12
# 68      2    R64     2    T12
# 71      2    R54     2    T29
# 73      2    R54     2    T29
# 74      1    NaN     2    T34
# 76      4    R80     1    NaN
# 82      2    R44     3    T67
# 88      1    NaN     1    NaN
# 93      1    NaN     1    NaN
# 99      1    NaN     2    T78
# 105     4    R69     1    NaN
#
# [13 rows x 21 columns]

# %%
df = df.where((pd.notnull(df)), 'None')

# %%
df.to_csv('out.csv')

# %%
type(df['RICDA'].iloc[0])
# Out:
# pandas.tslib.Timestamp

# %%
df
# Out:
#          RICDA UIC   LNAME ParentUIC  Parent level to child Parent Lname  UTC  \
# 56  2015-11-20  A1    Aone        B1                      1         Bone  XYZ
# 76  2015-11-20  A2    Atwo        B1                      1         Bone  XYZ
# 82  2015-11-20  A3  Athree        B1                      1         Bone  XYZ
# 93  2015-11-20  A4   Afour        B1                      1         Bone  XYZ
# 99  2015-11-21  A5   Afive        B1                      1         Bone  XYZ
# 105 2015-11-20  A6    Asix        B1                      1         Bone  XYZ
# 62  2015-11-23  B1    Bone        C1                      1         Cone  XYZ
# 88  2015-11-22  B2    Btwo        C1                      1         Cone  XYZ
# 67  2015-11-24  C1    Cone        D1                      1         Done  XYZ
# 68  2015-11-24  C1    Cone        D2                      1         Dtwo  XYZ
# 71  2015-11-25  D1    Eone        E1                      1         Eone  XYZ
# 73  2015-11-26  D2    Dtwo        E1                      1         Eone  XYZ
#
#     MJCOM_NAME SVC COMPOCD  ...   READY  REASN PRRAT  PRRES ESRAT  ESRES  \
# 56         ANG   F       G  ...       3      S     1   None     3    S85
# 76         ANG   F       G  ...       4      R     1   None     1   None
# 82         ANG   F       G  ...       3      T     1   None     1   None
# 93         ANG   F       G  ...       4      S     3    P43     4    S65
# 99         ANG   F       G  ...       2      T     1   None     1   None
# 105        ANG   F       G  ...       4      X     4    P18     3    S98
# 62         ANG   F       G  ...       3      T     1   None     1   None
# 88         ANG   F       G  ...       4      P     4    P19     2    S50
# 67         ANG   F       G  ...       2      X     2    P89     1   None
# 68         ANG   F       G  ...       2      X     2    P89     1   None
# 71         ANG   F       G  ...       3      S     2    P21     3    S40
# 73         ANG   F       G  ...       3      S     2    P81     3    S99
#
#     ERRAT  ERRES TRRAT  TRRES
# 56      1   None     1   None
# 76      4    R80     1   None
# 82      2    R44     3    T67
# 93      1   None     1   None
# 99      1   None     2    T78
# 105     4    R69     1   None
# 62      2    R53     3    T13
# 88      1   None     1   None
# 67      2    R64     2    T12
# 68      2    R64     2    T12
# 71      2    R54     2    T29
# 73      2    R54     2    T29
#
# [12 rows x 21 columns]

# %%
recent_date
# Out:
# Timestamp('2015-11-26 00:00:00')

# %%
df.head()
# Out:
#         RICDA UIC LNAME ParentUIC  Parent level to child Parent Lname  UTC  \
# 0  2015-10-19  A1  Aone        A1                      0         Aone  XYZ
# 1  2015-10-19  A1  Aone        B1                      1         Bone  XYZ
# 2  2015-10-19  A1  Aone        C1                      2         Cone  XYZ
# 3  2015-10-19  A1  Aone        D1                      3         Done  XYZ
# 4  2015-10-19  A1  Aone        D2                      3         Dtwo  XYZ
#
#   MJCOM_NAME SVC COMPOCD  ...   READY  REASN PRRAT  PRRES ESRAT  ESRES ERRAT  \
# 0        ANG   F       G  ...       3      S     1    NaN     3    S84     1
# 1        ANG   F       G  ...       3      S     1    NaN     3    S84     1
# 2        ANG   F       G  ...       3      S     1    NaN     3    S84     1
# 3        ANG   F       G  ...       3      S     1    NaN     3    S84     1
# 4        ANG   F       G  ...       3      S     1    NaN     3    S84     1
#
#    ERRES TRRAT  TRRES
# 0    NaN     1    NaN
# 1    NaN     1    NaN
# 2    NaN     1    NaN
# 3    NaN     1    NaN
# 4    NaN     1    NaN
#
# [5 rows x 21 columns]
